# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/flight.csv')
cols = ['dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'tailnum']
df[cols] = df[cols].fillna(df[cols].median())
df.head()
# Out:
#    dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay  \
# 0     517.0             515        2.0     830.0             819       11.0
# 1     533.0             529        4.0     850.0             830       20.0
# 2     542.0             540        2.0     923.0             850       33.0
# 3     544.0             545       -1.0    1004.0            1022      -18.0
# 4     554.0             600       -6.0     812.0             837      -25.0
#
#   carrier  flight tailnum origin dest  distance            time_hour
# 0      UA    1545  N14228    EWR  IAH      1400  2013-01-01 05:00:00
# 1      UA    1714  N24211    LGA  IAH      1416  2013-01-01 05:00:00
# 2      AA    1141  N619AA    JFK  MIA      1089  2013-01-01 05:00:00
# 3      B6     725  N804JB    JFK  BQN      1576  2013-01-01 05:00:00
# 4      DL     461  N668DN    LGA  ATL       762  2013-01-01 06:00:00

# %% [markdown]
# ### Sütun ve satır çıkarma

# %%
df = df.drop('dep_time', axis = 1)
df = df.iloc[50:]
df.head()
# Out:
#     sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay carrier  \
# 50             645        1.0    1023.0            1030       -7.0      UA
# 51             655       -4.0     936.0             942       -6.0      B6
# 52             655       -3.0     932.0             921       11.0      B6
# 53             700       -7.0     936.0            1009      -33.0      DL
# 54             655        0.0    1021.0            1030       -9.0      DL
#
#     flight tailnum origin dest  distance            time_hour
# 50    1496  N38727    EWR  SNA      2434  2013-01-01 06:00:00
# 51     203  N558JB    JFK  LAS      2248  2013-01-01 06:00:00
# 52     117  N178JB    JFK  MSY      1182  2013-01-01 06:00:00
# 53    1383  N327NW    LGA  PBI      1035  2013-01-01 07:00:00
# 54    1415  N3763D    JFK  SLC      1990  2013-01-01 06:00:00

# %% [markdown]
# ### Sütun ve satır ekleme

# %%
df['delay'] = df['dep_delay']+ df['arr_delay']
df = df.append(df.iloc[:8])
df.tail(8)
# Out:
#     sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay carrier  \
# 50             645        1.0    1023.0            1030       -7.0      UA
# 51             655       -4.0     936.0             942       -6.0      B6
# 52             655       -3.0     932.0             921       11.0      B6
# 53             700       -7.0     936.0            1009      -33.0      DL
# 54             655        0.0    1021.0            1030       -9.0      DL
#
#     flight tailnum origin dest  distance            time_hour  delay
# 50    1496  N38727    EWR  SNA      2434  2013-01-01 06:00:00   -6.0
# 51     203  N558JB    JFK  LAS      2248  2013-01-01 06:00:00  -10.0
# 52     117  N178JB    JFK  MSY      1182  2013-01-01 06:00:00    8.0
# 53    1383  N327NW    LGA  PBI      1035  2013-01-01 07:00:00  -40.0
# 54    1415  N3763D    JFK  SLC      1990  2013-01-01 06:00:00   -9.0

# %% [markdown]
# ### Farklı verisetlerini birleştirme (Alt alta)

# %%
pd.concat([df.head(), df.tail()],axis =0,ignore_index =True).head(6)
# Out:
#    sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay carrier  \
# 0             645        1.0    1023.0            1030       -7.0      UA
# 1             655       -4.0     936.0             942       -6.0      B6
# 2             655       -3.0     932.0             921       11.0      B6
# 3             700       -7.0     936.0            1009      -33.0      DL
# 4             655        0.0    1021.0            1030       -9.0      DL
# 5             645        1.0    1023.0            1030       -7.0      UA
#
#    flight tailnum origin dest  distance            time_hour  delay
# 0    1496  N38727    EWR  SNA      2434  2013-01-01 06:00:00   -6.0
# 1     203  N558JB    JFK  LAS      2248  2013-01-01 06:00:00  -10.0
# 2     117  N178JB    JFK  MSY      1182  2013-01-01 06:00:00    8.0
# 3    1383  N327NW    LGA  PBI      1035  2013-01-01 07:00:00  -40.0
# 4    1415  N3763D    JFK  SLC      1990  2013-01-01 06:00:00   -9.0
# 5    1496  N38727    EWR  SNA      2434  2013-01-01 06:00:00   -6.0

# %% [markdown]
# ### Farklı verisetlerini birleştirme (Yan Yana)

# %%
pd.concat([df.dep_delay, df.delay],axis =1).head(6)
# Out:
#     dep_delay  delay
# 50        1.0   -6.0
# 51       -4.0  -10.0
# 52       -3.0    8.0
# 53       -7.0  -40.0
# 54        0.0   -9.0
# 55       -5.0  -13.0

# %% [markdown]
# ### Kompleks Filtering

# %%
df[(df.arr_delay >50) & (df.arr_delay<100) & ((df.flight == 1545) | (df.flight == 1141))]
# Out:
#         sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay  \
# 10522              540      104.0    1025.0             850       95.0
# 33411             2000      115.0      16.0            2252       84.0
# 142802             540       12.0     950.0             850       60.0
# 182061            1830       96.0    2205.0            2100       65.0
# 186694            1830       83.0    2151.0            2100       51.0
# 207248            1830       77.0    2156.0            2100       56.0
# 213705            1830        7.0    2159.0            2100       59.0
# 231165            1729       87.0    2226.0            2059       87.0
# 247447            1729       45.0    2156.0            2059       57.0
# 248434            1729       73.0    2202.0            2059       63.0
# 257441            1822       96.0    2303.0            2155       68.0
# 258487            1822      120.0    2328.0            2155       93.0
# 260482            1822      104.0    2306.0            2155       71.0
# 278670            1822       10.0    2308.0            2155       73.0
# 284430            1822       30.0    2309.0            2155       74.0
# 288332            1822       19.0    2328.0            2155       93.0
# 300763            1748       70.0    2221.0            2125       56.0
#
#        carrier  flight tailnum origin dest  distance            time_hour  \
# 10522       AA    1141  N5DNAA    JFK  MIA      1089  2013-01-13 05:00:00
# 33411       UA    1545  N26208    EWR  IAH      1400  2013-10-07 20:00:00
# 142802      AA    1141  N631AA    JFK  MIA      1089  2013-03-08 05:00:00
# 182061      WN    1545  N910WN    EWR  MSY      1167  2013-04-18 18:00:00
# 186694      WN    1545  N715SW    EWR  MSY      1167  2013-04-23 18:00:00
# 207248      WN    1545  N778SW    EWR  MSY      1167  2013-05-15 18:00:00
# 213705      WN    1545  N795SW    EWR  MSY      1167  2013-05-22 18:00:00
# 231165      UA    1141  N87512    EWR  SFO      2565  2013-06-10 17:00:00
# 247447      UA    1141  N78509    EWR  SFO      2565  2013-06-27 17:00:00
# 248434      UA    1141  N76505    EWR  SFO      2565  2013-06-28 17:00:00
# 257441      UA    1141  N39415    EWR  SFO      2565  2013-07-08 18:00:00
# 258487      UA    1141  N75428    EWR  SFO      2565  2013-07-09 18:00:00
# 260482      UA    1141  N38459    EWR  SFO      2565  2013-07-11 18:00:00
# 278670      UA    1141  N75433    EWR  SFO      2565  2013-07-30 18:00:00
# 284430      UA    1141  N36472    EWR  SFO      2565  2013-08-05 18:00:00
# 288332      UA    1141  N39450    EWR  SFO      2565  2013-08-09 18:00:00
# 300763      UA    1141  N37474    EWR  SFO      2565  2013-08-22 17:00:00
#
#         delay
# 10522   199.0
# 33411   199.0
# 142802   72.0
# 182061  161.0
# 186694  134.0
# 207248  133.0
# 213705   66.0
# 231165  174.0
# 247447  102.0
# 248434  136.0
# 257441  164.0
# 258487  213.0
# 260482  175.0
# 278670   83.0
# 284430  104.0
# 288332  112.0
# 300763  126.0

# %% [markdown]
# ### Korelasyon Matrisi

# %%
a,x = plt.subplots(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True, linecolor='white', square = True, 
            linewidths= 0.1, vmax = 1, fmt= '.2f', cmap = 'RdBu',ax=x)
plt.title('Correlation between different features', y=1.03, size=18)
plt.show()

# %% [markdown]
# ### Histogram

# %%
a,x = plt.subplots(figsize=(12, 8))
df1 = df[df.arr_delay < 150]
plt.hist(df1.arr_delay, bins = int(180/3), edgecolor='black', color = 'red')
plt.title('Histogram of Arrival Delays')
plt.xlabel('Delay (min)')
plt.ylabel('Flights')
plt.show()

# %% [markdown]
# ### Dist-plot

# %%
a,x = plt.subplots(figsize=(12, 8))
import seaborn as sns 
sns.distplot(df1['arr_delay'],  
             bins=int(180/3), ax=x, hist_kws={'edgecolor':'black'}, color = 'r')
plt.title('Histogram of Arrival Delays')
plt.xlabel('Delay (min)')
plt.ylabel('Flights')
plt.show()
# Out:
# /home/stats/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Kde-plot

# %%
a,x = plt.subplots(figsize=(12, 8))
sns.kdeplot(df[(df.carrier=='UA')].distance,color = 'lime',label = 'UA')
sns.kdeplot(df[(df.carrier=='B6')].distance, color = 'blue',label = 'B6')
sns.kdeplot(df[(df.carrier=='EV')].distance,color = 'grey',label = 'EV')
plt.title("Arrival Delay")
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
a,x = plt.subplots(figsize=(12, 8))
sns.regplot(x=df["dep_delay"], y=df["arr_delay"], color = 'purple', ax=x)
plt.show()
